# %% [markdown]
# ## All Coral Species Phylogenetic Tree
# Taylor Lindsay

# %%
import Bio as Bio

# %%
from Bio import SeqIO
from Bio import AlignIO
from Bio import Phylo

# %%
# this data set is a published tree from Huang & Roy 2015 
# https://royalsocietypublishing.org/doi/10.1098/rstb.2014.0010
coral_tree = Phylo.read("Huang&Roy_Molecular.tre","nexus")

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10, 60), dpi=100) # create figure & set the size 
matplotlib.rc('font', size=6)              # fontsize of the leaf and node labels 
matplotlib.rc('xtick', labelsize=10)       # fontsize of the tick labels
matplotlib.rc('ytick', labelsize=10)       # fontsize of the tick labels
#turtle_tree.ladderize()
axes = fig.add_subplot(1, 1, 1)
Phylo.draw(coral_tree, axes=axes)
fig.savefig("coral_cladogram")
